# %% [markdown]
# ## **Librosa**

# %%
import librosa
import librosa.display
from matplotlib import pyplot as plt

# %%
wavefile="/content/drive/MyDrive/Datasets/Bengali(new)/ben_0001.wav"

# %%
signal,sample_rate=librosa.load(wavefile)

# %%
signal
# Out:
# array([0.00469805, 0.00422034, 0.00362488, ..., 0.00119794, 0.00076718,
#        0.        ], dtype=float32)

# %%
sample_rate
# Out:
# 22050

# %%
# plt.figure(figsize=(14,5))
librosa.display.waveplot(signal,sample_rate)

# %%
import glob

# %%
myfolder1="/content/drive/MyDrive/Datasets/Bengali(new)"

# %%
myfolder1
# Out:
# '/content/drive/MyDrive/Datasets/Bengali(new)'

# %%
def getwave(path):
  # print(path)
  wave=glob.glob(path + "/*.wav")
  # print(wave)
  plt.figure(figsize=(14,5))
  for i in wave:
    signal,sample_rate=librosa.load(i)
    librosa.display.waveplot(signal,sr=1000)

# %%
getwave(myfolder1)

# %%
myfolder2="/content/drive/MyDrive/Datasets/Hindi(new)"

# %%
def getwave(path):
  # print(path)
  wave=glob.glob(path + "/*.wav")
  # print(wave)
  plt.figure(figsize=(14,5))
  for i in wave:
    signal,sample_rate=librosa.load(i)
    librosa.display.waveplot(signal,sr=1000)

# %%
getwave(myfolder2)

# %%
myfolder3="/content/drive/MyDrive/Datasets/Kannada(new)"

# %%
def getwave(path):
  # print(path)
  wave=glob.glob(path + "/*.wav")
  # print(wave)
  plt.figure(figsize=(14,5))
  for i in wave:
    signal,sample_rate=librosa.load(i)
    librosa.display.waveplot(signal,sr=1000)

# %%
getwave(myfolder3)

# %%
myfolder4="/content/drive/MyDrive/Datasets/Kannada(new)"

# %%
def getwave(path):
  # print(path)
  wave=glob.glob(path + "/*.wav")
  # print(wave)
  plt.figure(figsize=(14,5))
  for i in wave:
    signal,sample_rate=librosa.load(i)
    librosa.display.waveplot(signal,sr=1000)

# %%
getwave(myfolder4)

# %%
myfolder5="/content/drive/MyDrive/Datasets/Malayalam(new)"

# %%
def getwave(path):
  # print(path)
  wave=glob.glob(path + "/*.wav")
  # print(wave)
  plt.figure(figsize=(14,5))
  for i in wave:
    signal,sample_rate=librosa.load(i)
    librosa.display.waveplot(signal,sr=1000)

# %%
getwave(myfolder5)

# %% [markdown]
# # Dataframe

# %%
import pandas as pd
def getwavefile(path):
  # print(path)
  wavefile=glob.glob(path + "/*.wav")
  return wavefile

# %%
data=getwavefile(myfolder1)
df=pd.DataFrame(data,columns=['Filename'])
df
# Out:
#                                             Filename
# 0  /content/drive/MyDrive/Datasets/Bengali(new)/b...
# 1  /content/drive/MyDrive/Datasets/Bengali(new)/b...
# 2  /content/drive/MyDrive/Datasets/Bengali(new)/b...
# 3  /content/drive/MyDrive/Datasets/Bengali(new)/b...
# 4  /content/drive/MyDrive/Datasets/Bengali(new)/b...
# 5  /content/drive/MyDrive/Datasets/Bengali(new)/b...
# 6  /content/drive/MyDrive/Datasets/Bengali(new)/b...
# 7  /content/drive/MyDrive/Datasets/Bengali(new)/b...
# 8  /content/drive/MyDrive/Datasets/Bengali(new)/b...
# 9  /content/drive/MyDrive/Datasets/Bengali(new)/b...

# %% [markdown]
# # converting dataframe to csv

# %%
csv_data=df.to_csv(header=True)
df.to_csv('/content/drive/MyDrive/out.csv')
print(csv_data)
# Out:
# ,Filename
# 0,/content/drive/MyDrive/Datasets/Bengali(new)/ben_0007.wav
# 1,/content/drive/MyDrive/Datasets/Bengali(new)/ben_0006.wav
# 2,/content/drive/MyDrive/Datasets/Bengali(new)/ben_0002.wav
# 3,/content/drive/MyDrive/Datasets/Bengali(new)/ben_0004.wav
# 4,/content/drive/MyDrive/Datasets/Bengali(new)/ben_0008.wav
# 5,/content/drive/MyDrive/Datasets/Bengali(new)/ben_0005.wav
# 6,/content/drive/MyDrive/Datasets/Bengali(new)/ben_0010.wav
# 7,/content/drive/MyDrive/Datasets/Bengali(new)/ben_0003.wav
# 8,/content/drive/MyDrive/Datasets/Bengali(new)/ben_0009.wav
# 9,/content/drive/MyDrive/Datasets/Bengali(new)/ben_0001.wav

# %%
#reading csv file 
csv_file=pd.read_csv('/content/drive/MyDrive/out.csv')
meta=pd.DataFrame(csv_file)

# %%
csv_file
# Out:
#    Unnamed: 0                                           Filename
# 0           0  /content/drive/MyDrive/Datasets/Bengali(new)/b...
# 1           1  /content/drive/MyDrive/Datasets/Bengali(new)/b...
# 2           2  /content/drive/MyDrive/Datasets/Bengali(new)/b...
# 3           3  /content/drive/MyDrive/Datasets/Bengali(new)/b...
# 4           4  /content/drive/MyDrive/Datasets/Bengali(new)/b...
# 5           5  /content/drive/MyDrive/Datasets/Bengali(new)/b...
# 6           6  /content/drive/MyDrive/Datasets/Bengali(new)/b...
# 7           7  /content/drive/MyDrive/Datasets/Bengali(new)/b...
# 8           8  /content/drive/MyDrive/Datasets/Bengali(new)/b...
# 9           9  /content/drive/MyDrive/Datasets/Bengali(new)/b...

# %%
import numpy as np

# %%
def get_voice_data(_path):
  wavefiles=glob.glob(_path + "/*.wav")

  meanlist=[]
  stdlist=[]
  maxvlist=[]

# %%
import os
import glob

# %%
folder_path = '/content/drive/MyDrive/Datasets'

for filename in glob.glob(os.path.join(folder_path,'*.wav')):

# %%
# Import Module
import os

# %%
# Folder Path
path = "/content/drive/MyDrive/Datasets"
  
# Change the directory
os.chdir(path)

# %%
path
# Out:
# '/content/drive/MyDrive/Datasets'

# %%
# def read_wav_file(path):
#     wave=glob.glob(path + "/*.wav")
#     print(wave)

# read_wav_file(path)

# %%
os.listdir()
# Out:
# ['IIIT Spoken Language Datasets',
#  'Bengali(new)',
#  'Hindi(new)',
#  'Kannada(new)',
#  'Malayalam(new)',
#  'Marathi(new)',
#  'Tamil(new)',
#  'Telugu(new)']

# %%
path
# Out:
# '/content/drive/MyDrive/Datasets'

# %%
def read_wav_file(path):
    for i in path:
      print("*******",i)
      wave=glob.glob(path + "/*.wav")
      signal, sample_rate=librosa.load(i)
      #librosa.display.waveplot(signal,sr=1000)
      print('------')

# %%
# iterate through all file
for file in os.listdir():
    # Check whether file is in text format or not
    #print(file)
    file_path = f"{path}/{file}"
    #print(file_path)
    read_wav_file(file_path)
        # call read text file function
        #read_text_file(file_path)

# %%
0 
# to read .wav files from multiple folders   
  
def read_wav_file(path):
    wave=glob.glob(path + "/*.wav")
    with open(path, 'r') as f:
        print(f.read())
  


  # print(path)
  wave=glob.glob(path + "/*.wav")
  # print(wave)
  plt.figure(figsize=(14,5))
  for i in wave:
    signal,sample_rate=librosa.load(i)
    librosa.display.waveplot(signal,sr=1000)
  
# iterate through all file
for file in os.listdir():
    # Check whether file is in text format or not
    if file.endswith(".wav"):
        file_path = f"{path}\{file}"
  
        # call read text file function
        read_text_file(file_path)


        signal,sample_rate=librosa.load(i)
    librosa.display.waveplot(signal,sr=1000)
# Out:
#   File "<tokenize>", line 12
#     wave=glob.glob(path + "/*.wav")
#     ^
# IndentationError: unindent does not match any outer indentation level

# %% [markdown]
# # **labelling**
