# %% [markdown]
# ## **Librosa**

# %%
import librosa
import librosa.display
from matplotlib import pyplot as plt

# %%
wavefile="/content/drive/MyDrive/sample dataset/Bengali/Copy of ben_0001.wav"

# %%
signal,sample_rate=librosa.load(wavefile)
# Out:
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# ---------------------------------------------------------------------------
# LibsndfileError                           Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     148     try:
# --> 149         with sf.SoundFile(path) as sf_desc:
#     150             sr_native = sf_desc.samplerate
#
# /usr/local/lib/python3.8/dist-packages/soundfile.py in __init__(self, file, mode, samplerate, channels, subtype, endian, format, closefd)
#     654                                          format, subtype, endian)
# --> 655         self._file = self._open(file, mode_int, closefd)
#     656         if set(mode).issuperset('r+') and self.seekable():
#
# /usr/local/lib/python3.8/dist-packages/soundfile.py in _open(self, file, mode_int, closefd)
#    1212             err = _snd.sf_error(file_ptr)
# -> 1213             raise LibsndfileError(err, prefix="Error opening {0!r}: ".format(self.name))
#    1214         if mode_int == _snd.SFM_WRITE:
#
# LibsndfileError: Error opening '/content/drive/MyDrive/sample dataset/Bengali/Copy of ben_0001.wav': System error.
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-e8a16637ec68> in <module>
# ----> 1 signal,sample_rate=librosa.load(wavefile)
#
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     164         if isinstance(path, (str, pathlib.PurePath)):
#     165             warnings.warn("PySoundFile failed. Trying audioread instead.")
# --> 166             y, sr_native = __audioread_load(path, offset, duration, dtype)
#     167         else:
#     168             raise (exc)
#
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py in __audioread_load(path, offset, duration, dtype)
#     188
#     189     y = []
# --> 190     with audioread.audio_open(path) as input_file:
#     191         sr_native = input_file.samplerate
#     192         n_channels = input_file.channels
#
# /usr/local/lib/python3.8/dist-packages/audioread/__init__.py in audio_open(path, backends)
#     125     for BackendClass in backends:
#     126         try:
# --> 127             return BackendClass(path)
#     128         except DecodeError:
#     129             pass
#
# /usr/local/lib/python3.8/dist-packages/audioread/rawread.py in __init__(self, filename)
#      57     """
#      58     def __init__(self, filename):
# ---> 59         self._fh = open(filename, 'rb')
#      60
#      61         try:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/sample dataset/Bengali/Copy of ben_0001.wav'

# %%
signal
# Out:
# array([0.00469805, 0.00422034, 0.00362488, ..., 0.00119794, 0.00076718,
#        0.        ], dtype=float32)

# %%
sample_rate
# Out:
# 22050

# %%
plt.figure(figsize=(14,5))
librosa.display.waveplot(signal,sample_rate)

# %%
import glob

# %%
myfolder1="/content/drive/MyDrive/sample dataset/Bengali"

# %%
myfolder1
# Out:
# '/content/drive/MyDrive/Datasets/Bengali(new)'

# %%
def getwave(path):
  # print(path)
  wave=glob.glob(path + "/*.wav")
  # print(wave)
  plt.figure(figsize=(14,5))
  for i in wave:
    signal,sample_rate=librosa.load(i)
    librosa.display.waveplot(signal,sr=1000)

# %%
getwave(myfolder1)

# %%
myfolder2="/content/drive/MyDrive/Datasets/Hindi(new)"

# %%
def getwave(path):
  # print(path)
  wave=glob.glob(path + "/*.wav")
  # print(wave)
  plt.figure(figsize=(14,5))
  for i in wave:
    signal,sample_rate=librosa.load(i)
    librosa.display.waveplot(signal,sr=1000)

# %%
getwave(myfolder2)

# %%
myfolder3="/content/drive/MyDrive/Datasets/Kannada(new)"

# %%
def getwave(path):
  # print(path)
  wave=glob.glob(path + "/*.wav")
  # print(wave)
  plt.figure(figsize=(14,5))
  for i in wave:
    signal,sample_rate=librosa.load(i)
    librosa.display.waveplot(signal,sr=1000)

# %%
getwave(myfolder3)

# %%
myfolder4="/content/drive/MyDrive/Datasets/Kannada(new)"

# %%
def getwave(path):
  # print(path)
  wave=glob.glob(path + "/*.wav")
  # print(wave)
  plt.figure(figsize=(14,5))
  for i in wave:
    signal,sample_rate=librosa.load(i)
    librosa.display.waveplot(signal,sr=1000)

# %%
getwave(myfolder4)

# %%
myfolder5="/content/drive/MyDrive/Datasets/Malayalam(new)"

# %%
def getwave(path):
  # print(path)
  wave=glob.glob(path + "/*.wav")
  # print(wave)
  plt.figure(figsize=(20,5))
  for i in wave:
    signal,sample_rate=librosa.load(i)
    librosa.display.waveplot(signal,sr=1000)

# %%
getwave(myfolder5)

# %% [markdown]
# # Dataframe

# %%
import pandas as pd

# %%
def getwavefile(path):
  # print(path)
  wavefile=glob.glob(path + "/*.wav")
  return wavefile

# %%
data=getwavefile(myfolder5)

# %%
df=pd.DataFrame(data,columns=['Filename'])

# %%
df

# %% [markdown]
# # Mean median calculating

# %%
import numpy as np

# %%
def get_voice_data(_path):
  wavefiles=glob.glob(_path + "/*.wav")

  meanlist=[]
  stdlist=[]
  maxvlist=[]

  type_list= []
  n_list= []
# # for wav_file in wav_files:
  for wav_file in wav_files: # tqdm shows the progress bar
      x, sr = librosa.load(wav_file)
      freqs = np.fft.fftfreq(x.size)

      mean = 0
      std = 0
      maxv = 0
      minv = 0
      median = 0

      mean = np.mean(freqs)
      std = np.std(freqs)
      maxv = np.amax(freqs)
      minv = np.amin(freqs)
      median = np.median(freqs)
      
      mean_list.append(mean)
      std_list.append(std)
      maxv_list.append(maxv)
      minv_list.append(minv)
      median_list.append(median)
      type_list.append(wav_file[7])

# %%
import os
import glob

# %%
folder_path = '/content/drive/MyDrive/Datasets'

for filename in glob.glob(os.path.join(folder_path,'*.wav')):
# Out:
#   File "<ipython-input-37-a627bd6f0063>", line 3
#     for filename in glob.glob(os.path.join(folder_path,'*.wav')):
#                                                                  ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# # --------------------------exp------------------------------------------

# %%
# Import Module
import os

# %%
# Folder Path
path = "/content/drive/MyDrive/Datasets"
  
# Change the directory
os.chdir(path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-2c9d5a9ae859> in <module>
#       3
#       4 # Change the directory
# ----> 5 os.chdir(path)
#
# NameError: name 'os' is not defined

# %%
path1=os.listdir()
path1
# Out:
# ['.config', 'sample_data']

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def preprocess(signal, samplerate):
    print('Sample rate: ', samplerate)
    sum=0
    for i in range(len(signal)):
        sum = sum+signal[i]
    print('sum : ', sum)

# %%
def read_wav_file(path):
    wave=glob.glob(path + "/*.wav")
    for i in wave:
      print('wave : ', i)
      signal, sample_rate=librosa.load(i)
      print('length : ', len(signal))
      preprocess(signal, sample_rate)
      print('signal :', signal)

      print('--------------------------------------------------------------------------')
      #librosa.display.waveplot(signal,sr=1000)
      #print('---------')

# %%
path = '/content/drive/MyDrive/Datasets/Bengali(new)'
read_wav_file(path)

# %%
print(signal, sample_rate)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-80d1826dce3d> in <module>
# ----> 1 print(signal, sample_rate)
#
# NameError: name 'signal' is not defined

# %%
# iterate through all file
for file in os.listdir():
    # Check whether file is in text format or not
    #print(file)
    file_path = f"{path}/{file}"
    print(file_path)
    read_wav_file(file_path)  # calling function to read wav files in a folder
# Out:
# /content/drive/MyDrive/Datasets/Bengali(new)/.config
# /content/drive/MyDrive/Datasets/Bengali(new)/sample_data

# %%
b=[]
print('b : ', b)
a=2
b.append(a)
print('a : ', a)
print('b : ', b)

a=5
b.append(a)
print('a : ', a)
print('b : ', b)

a=10
b.append(a)
print('a : ', a)
print('b : ', b)
a
b
# Out:
# b :  []
# a :  2
# b :  [2]
# a :  5
# b :  [2, 5]
# a :  10
# b :  [2, 5, 10]
# [2, 5, 10]

# %% [markdown]
# # MFCC

# %%
import librosa

# %%
y, sr = librosa.load("/content/drive/MyDrive/mar_0001.wav")
y
# librosa.feature.mfcc(y=y, sr=sr)
# Out:
# array([-2.7820359e-03, -3.5054456e-03, -3.1800980e-03, ...,
#        -2.4401760e-04, -8.5327658e-05,  0.0000000e+00], dtype=float32)

# %%
sr
# Out:
# 22050

# %%
plt.figure(figsize=(14,5))
librosa.display.waveplot(y,sr)

# %%
plt.figure(figsize=(14,5))
librosa.display.waveplot(y,sr)

# %%
y, sr = librosa.load("/content/drive/MyDrive/mar_0001.wav",sr=1000)
y
# Out:
# array([-0.00168433, -0.00369513, -0.00248803, ..., -0.00069003,
#        -0.0006546 ,  0.        ], dtype=float32)

# %%
g=librosa.feature.mfcc(y=y, sr=sr, n_mfcc=12)

# %%
g
# Out:
# array([[-224.58983  , -142.29524  , -119.80634  , -110.6522   ,
#         -127.90752  , -160.27272  , -128.1282   , -151.16295  ,
#         -227.76035  ],
#        [  15.345364 ,   -6.6010303,    2.3052402,   -3.7958975,
#           -3.9709575,   29.923203 ,   19.513813 ,   20.991543 ,
#           49.49517  ],
#        [ -18.1302   ,  -50.228912 ,  -58.364613 ,  -48.71496  ,
#          -59.24887  ,  -82.16951  ,  -68.24239  ,  -60.139378 ,
#          -46.230907 ],
#        [  19.902973 ,   12.601756 ,   15.158821 ,   15.377504 ,
#           18.942947 ,   22.486    ,   18.328459 ,   25.304846 ,
#           33.124702 ],
#        [ -33.09694  ,  -48.481377 ,  -55.55346  ,  -53.143658 ,
#          -49.69326  ,  -37.29888  ,  -50.193848 ,  -42.130608 ,
#          -28.447268 ],
#        [  18.76593  ,   24.134346 ,   33.781025 ,   42.18172  ,
#           27.03626  ,   12.126984 ,   29.204645 ,   43.05188  ,
#           44.879982 ],
#        [ -50.881138 ,  -45.100845 ,  -45.219772 ,  -44.512337 ,
#          -41.338196 ,  -33.01329  ,  -42.803734 ,  -55.377678 ,
#          -44.81806  ],
#        [  18.33265  ,   50.69154  ,   50.482567 ,   14.452418 ,
#           33.350266 ,   62.16271  ,   37.28031  ,   14.7797165,
#           11.006063 ],
#        [  16.410517 ,   12.75721  ,    3.440932 ,   -6.002025 ,
#          -15.804441 ,  -36.669918 ,  -41.241142 ,  -38.956047 ,
#          -28.276001 ],
#        [   7.785161 ,    5.982236 ,   27.308931 ,   51.588593 ,
#           32.317627 ,    9.760643 ,   31.230827 ,   33.756157 ,
#            0.9615867],
#        [ -31.200546 ,  -38.221264 ,  -34.79889  ,  -23.78476  ,
#          -17.051468 ,   -9.854765 ,    3.7923956,   13.69821  ,
#           17.935032 ],
#        [   9.60265  ,    7.4620857,   23.403252 ,   42.400402 ,
#           43.782555 ,   27.340797 ,   34.820045 ,   51.613144 ,
#           47.696434 ]], dtype=float32)

# %%
g.shape
# Out:
# (12, 9)

# %%
plt.imshow(g)
